# %% [markdown]
# # 04 - Ciclos y Colecciones: for, while, listas y tuplas
#
# ## Objetivos de Aprendizaje
#
# En esta sesión aprenderás:
#
# 1. ✅ Usar ciclos `for` para iterar sobre rangos y colecciones
# 2. ✅ Controlar ciclos con `while`, `break` y `continue`
# 3. ✅ Crear y manipular listas (indexado, slicing, métodos básicos)
# 4. ✅ Comprender cuándo usar tuplas y cómo desempaquetarlas
# 5. ✅ Resolver problemas prácticos combinando ciclos y colecciones
#
# ---
#
# ## Ruta de la sesión (secuencia ideal)
#
# 1. `for` con `range()` y con listas
# 2. `while` y control de flujo
# 3. `break` y `continue`
# 4. Listas: creación, acceso, mutabilidad y métodos
# 5. Iteración y acumuladores (sumas, conteos)
# 6. Tuplas: inmutabilidad y uso práctico
# 7. Ejercicios integradores

# %% [markdown]
# ## 1. Ciclo `for`
#
# El ciclo `for` se usa para **iterar** sobre una secuencia (rango, lista, string, etc.).

# %%
# for con range()
for i in range(5):
    print(i)

print("---")

# range(inicio, fin, paso)
for i in range(2, 11, 2):
    print(i)

# %%
# for con lista
frutas = ["manzana", "pera", "uva"]
for fruta in frutas:
    print(fruta)

# %% [markdown]
# ## 2. Ciclo `while`
#
# El ciclo `while` se repite **mientras** una condición sea verdadera.

# %%
# while con contador
contador = 1
while contador <= 5:
    print(contador)
    contador += 1

# %%
# while con condición de salida (simulación de input)
entrada = ""
intentos = 0

while entrada != "python" and intentos < 3:
    # En un script real usarías: entrada = input("Palabra secreta: ")
    entrada = "python" if intentos == 2 else "error"
    intentos += 1

print(f"Intentos usados: {intentos}")
print(f"¿Acceso permitido?: {entrada == 'python'}")

# %% [markdown]
# ## 3. Control del ciclo: `break` y `continue`
#
# - `break`: rompe el ciclo inmediatamente.
# - `continue`: salta a la siguiente iteración.

# %%
# break
numeros = [3, 5, 7, 9, 12, 15]
for n in numeros:
    if n % 2 == 0:
        print(f"Encontré el primer par: {n}")
        break

# %%
# continue
for n in range(1, 6):
    if n == 3:
        continue
    print(n)

# %% [markdown]
# ## 4. Listas
#
# Las listas son **colecciones ordenadas y mutables**.

# %%
# Crear listas
numeros = [10, 20, 30]
mezcla = ["Ana", 21, True, 3.14]

# Acceso por índice
print(numeros[0])
print(numeros[-1])

# Slicing
print(numeros[0:2])

# %%
# Métodos comunes
nombres = ["Luis", "Marta", "Sofía"]

nombres.append("Carlos")
print(nombres)

nombres.insert(1, "Iván")
print(nombres)

nombres.remove("Marta")
print(nombres)

ultimo = nombres.pop()
print(f"Se eliminó: {ultimo}")
print(nombres)

# %% [markdown]
# ## 5. Iteración con acumuladores
#
# Un patrón clásico es **acumular** resultados al recorrer una lista.

# %%
# Suma de elementos
calificaciones = [80, 90, 75, 88]

suma = 0
for cal in calificaciones:
    suma += cal

promedio = suma / len(calificaciones)
print(f"Promedio: {promedio:.2f}")

# %% [markdown]
# ## 6. Tuplas
#
# Las tuplas son **colecciones ordenadas e inmutables**. Útiles cuando los datos no deben cambiar.

# %%
# Crear tuplas
punto = (10, 5)
colores = ("rojo", "verde", "azul")

print(punto[0])
print(colores[-1])

# %%
# Desempaquetado de tuplas
x, y = punto
print(f"x = {x}, y = {y}")

# %% [markdown]
# ## 7. Ejercicios Prácticos
#
# Resuelve los siguientes ejercicios. Cada uno incluye una propuesta de solución.

# %% [markdown]
# ### Ejercicio 1: Suma de 1 a N
#
# **Tarea**: Calcula la suma de los números del 1 al N usando `for`.

# %%
# Tu código aquí:
# n = 10
# ...

# SOLUCIÓN:
n = 10
suma = 0
for i in range(1, n + 1):
    suma += i
print(f"Suma 1..{n} = {suma}")

# %% [markdown]
# ### Ejercicio 2: Contar pares
#
# **Tarea**: Dada una lista, cuenta cuántos números son pares.

# %%
# Tu código aquí:
# numeros = [1, 2, 3, 4, 5, 6]
# ...

# SOLUCIÓN:
numeros = [1, 2, 3, 4, 5, 6]
pares = 0
for n in numeros:
    if n % 2 == 0:
        pares += 1
print(f"Pares: {pares}")

# %% [markdown]
# ### Ejercicio 3: Filtrar mayores a un umbral
#
# **Tarea**: Crea una nueva lista con las calificaciones >= 70.

# %%
# Tu código aquí:
# calificaciones = [55, 70, 82, 64, 90]
# ...

# SOLUCIÓN:
calificaciones = [55, 70, 82, 64, 90]
filtradas = []
for cal in calificaciones:
    if cal >= 70:
        filtradas.append(cal)
print(filtradas)

# %% [markdown]
# ### Ejercicio 4: Tabla de multiplicar
#
# **Tarea**: Imprime la tabla del 7 (del 1 al 10) usando `for`.

# %%
# Tu código aquí:
# ...

# SOLUCIÓN:
for i in range(1, 11):
    print(f"7 x {i} = {7 * i}")

# %% [markdown]
# ### Ejercicio 5: Coordenadas (tuplas)
#
# **Tarea**: Dada una lista de tuplas (x, y), calcula la suma de todos los x y todos los y.

# %%
# Tu código aquí:
# puntos = [(1, 2), (3, 4), (5, 6)]
# ...

# SOLUCIÓN:
puntos = [(1, 2), (3, 4), (5, 6)]

suma_x = 0
suma_y = 0
for x, y in puntos:
    suma_x += x
    suma_y += y

print(f"Suma x: {suma_x}, Suma y: {suma_y}")

# %% [markdown]
# ## 8. Resumen de Conceptos Clave
#
# | Concepto | Qué es | Ejemplo |
# |----------|--------|---------|
# | `for` | Itera sobre secuencias | `for i in range(5)` |
# | `while` | Repite mientras condición sea true | `while x < 10` |
# | `break` | Rompe el ciclo | `break` |
# | `continue` | Salta iteración | `continue` |
# | Listas | Colección mutable | `[1, 2, 3]` |
# | Tuplas | Colección inmutable | `(1, 2)` |
#
# ## Buenas Prácticas ✅
#
# 1. ✅ Evita ciclos infinitos: siempre actualiza la condición en `while`
# 2. ✅ Usa nombres claros (`calificaciones`, `contador`, `suma`)
# 3. ✅ Prefiere `for` si conoces la cantidad de iteraciones
# 4. ✅ Valida datos antes de operar con listas vacías
# 5. ✅ Usa tuplas cuando los datos no deben cambiar
#
# ---
#
# ## 🚀 Próxima Sesión
#
# - **Sesión 5**: Strings a fondo (métodos útiles, formato, validaciones)
